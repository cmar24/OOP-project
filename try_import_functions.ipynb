# %%
from scanpy import *

pbmc = datasets.pbmc68k_reduced()

# %%
from scanpy.plotting.plot import umap_din

umap_din(pbmc)
# Out:
# C:\Users\34619\entorno_virtual\Lib\site-packages\holoviews\core\data\pandas.py:239: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dataset.data.groupby(group_by, sort=False)]
# :NdOverlay   [Louvain]
#    :Scatter   [UMAP_X]   (UMAP_Y)

# %%
from scanpy.export._expressed_genes import find_top_expressed_genes

x_cord = -3.974
y_cord = 7.690
find_top_expressed_genes(x_cord, y_cord, pbmc)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 from scanpy.export._expressed_genes import find_top_expressed_genes
#       3 x_cord = -3.974
#       4 y_cord = 7.690
#
# ImportError: cannot import name 'find_top_expressed_genes' from 'scanpy.export._expressed_genes' (C:\Users\34619\scanpy_project\OOP-project\scanpy\export\_expressed_genes.py)
